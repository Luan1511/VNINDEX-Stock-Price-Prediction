# %% [markdown]
# <a href="https://colab.research.google.com/github/Luan1511/VNINDEX-Stock-Price-Prediction/blob/main/VNINDEX_Stock_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # 1- Bussiness Problem

# %% [markdown]
# #### Date: Represents the date of the relevant trading day.
# #### Open: Represents the starting price of the stock for the relevant trading day.
# #### High: Represents the highest price for the relevant trading day.
# #### Low: Represents the lowest price for the relevant trading day.
# #### Close: Represents the closing price of the stock on the relevant trading day.
# #### Adj Close: Represents the adjusted closing price of the stock for the relevant trading day. (This accounts for things like stock splits and dividends.)
# #### Volume: Represents the trading volume information for the relevant trading day.

# %% [markdown]
# # 2- Understanding Data

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Dropout
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping

import warnings
warnings.filterwarnings("ignore")

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
import kagglehub

path = kagglehub.dataset_download("keithvo/vnstockdata")

print("Path to dataset files:", path)

for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Path to dataset files: /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/USDVND1D.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN100H4.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVNINDEXH4.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVNINDEXH1.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN100H1.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVNINDEXM30.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVNINDEX1D.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN30H1.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN30H4.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN30M30.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN1001D.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN100M30.csv
# /root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVN301D.csv

# %%
#data=pd.read_csv("../input/tesla-stock-data-from-2010-to-2020/TSLA.csv")
#data=pd.read_csv('/kaggle/input/tesla-csv/Tasla_Stock_Updated_V2.csv')
# data=pd.read_csv('/kaggle/input/vnindex1/merged_VNINDEX (1).csv')
data=pd.read_csv('/root/.cache/kagglehub/datasets/keithvo/vnstockdata/versions/1/HOSEVNINDEX1D.csv')

# %%
data.tail()
# Out:
#             time     open     high      low    close        55EMA  \
# 5889  1733191200  1251.21  1253.83  1244.91  1249.83  1252.206025
# 5890  1733277600  1249.83  1249.83  1239.82  1240.41  1251.784739
# 5891  1733364000  1241.81  1269.18  1238.49  1267.53  1252.347069
# 5892  1733450400  1270.96  1276.10  1268.58  1270.14  1252.982531
# 5893  1733709600  1270.14  1277.69  1268.69  1273.84  1253.727441
#
#             89EMA       200EMA  Plot
# 5889  1254.611617  1242.064889   NaN
# 5890  1254.296026  1242.048423   NaN
# 5891  1254.590114  1242.301971   NaN
# 5892  1254.935667  1242.578966   NaN
# 5893  1255.355763  1242.890021   NaN

# %%
def check_df(dataframe,head=5):
    print("#################### Shape #################### ")
    print(dataframe.shape)
    print("#################### Types #################### ")
    print(dataframe.dtypes)
    print("#################### Head #################### ")
    print(dataframe.head(head))
    print("#################### Tail #################### ")
    print(dataframe.dtypes)
    print("#################### NA #################### ")
    print(dataframe.isnull().sum())
    print("#################### Quantiles #################### ")
    print(dataframe.quantile([0,0.5,0.50,0.95,0.99,1]).T)

# %%
check_df(data)
# Out:
# #################### Shape ####################
# (5894, 9)
# #################### Types ####################
# time        int64
# open      float64
# high      float64
# low       float64
# close     float64
# 55EMA     float64
# 89EMA     float64
# 200EMA    float64
# Plot      float64
# dtype: object
# #################### Head ####################
#         time        open        high         low       close  55EMA  89EMA  \
# 0  964749600  100.000000  100.000000  100.000000  100.000000    NaN    NaN
# 1  965008800  101.550003  101.550003  101.550003  101.550003    NaN    NaN
# 2  965181600  103.379997  103.379997  103.379997  103.379997    NaN    NaN
# 3  965354400  105.199997  105.199997  105.199997  105.199997    NaN    NaN
# 4  965613600  106.919998  106.919998  106.919998  106.919998    NaN    NaN
#
#    200EMA  Plot
# 0     NaN   NaN
# 1     NaN   NaN
# 2     NaN   NaN
# 3     NaN   NaN
# 4     NaN   NaN
# #################### Tail ####################
# time        int64
# open      float64
# high      float64
# low       float64
# close     float64
# 55EMA     float64
# 89EMA     float64
# 200EMA    float64
# Plot      float64
# dtype: object
# #################### NA ####################
# time         0
# open         0
# high         0
# low          0
# close        0
# 55EMA       54
# 89EMA       88
# 200EMA     199
# Plot      5894
# dtype: int64
# #################### Quantiles ####################
#                 0.00          0.50          0.50          0.95          0.99  \
# time    9.647496e+08  1.359382e+09  1.359382e+09  1.696501e+09  1.726544e+09
# open    1.000000e+02  5.640350e+02  5.640350e+02  1.280086e+03  1.481777e+03
# high    1.000000e+02  5.681900e+02  5.681900e+02  1.286840e+03  1.490459e+03
# low     1.000000e+02  5.611600e+02  5.611600e+02  1.271872e+03  1.470147e+03
# close   1.000000e+02  5.634850e+02  5.634850e+02  1.280007e+03  1.478968e+03
# 55EMA   1.302265e+02  5.656758e+02  5.656758e+02  1.267086e+03  1.466724e+03
# 89EMA   1.410888e+02  5.671343e+02  5.671343e+02  1.268654e+03  1.449332e+03
# 200EMA  1.511279e+02  5.735449e+02  5.735449e+02  1.242607e+03  1.388081e+03
# Plot             NaN           NaN           NaN           NaN           NaN
#
#                 1.00
# time    1.733710e+09
# open    1.533620e+03
# high    1.536450e+03
# low     1.524960e+03
# close   1.528570e+03
# 55EMA   1.488951e+03
# 89EMA   1.476168e+03
# 200EMA  1.414965e+03
# Plot             NaN

# %% [markdown]
# #### we need to change the date variable

# %%
data["time"]=pd.to_datetime(data["time"])

# %%
data.tail()
# Out:
#                               time     open     high      low    close  \
# 5889 1970-01-01 00:00:01.733191200  1251.21  1253.83  1244.91  1249.83
# 5890 1970-01-01 00:00:01.733277600  1249.83  1249.83  1239.82  1240.41
# 5891 1970-01-01 00:00:01.733364000  1241.81  1269.18  1238.49  1267.53
# 5892 1970-01-01 00:00:01.733450400  1270.96  1276.10  1268.58  1270.14
# 5893 1970-01-01 00:00:01.733709600  1270.14  1277.69  1268.69  1273.84
#
#             55EMA        89EMA       200EMA  Plot
# 5889  1252.206025  1254.611617  1242.064889   NaN
# 5890  1251.784739  1254.296026  1242.048423   NaN
# 5891  1252.347069  1254.590114  1242.301971   NaN
# 5892  1252.982531  1254.935667  1242.578966   NaN
# 5893  1253.727441  1255.355763  1242.890021   NaN

# %% [markdown]
# # 3- Preparing the Data

# %%
vnindex_data=data[["time","close"]]
vnindex_data.head()
# Out:
#                            time       close
# 0 1970-01-01 00:00:00.964749600  100.000000
# 1 1970-01-01 00:00:00.965008800  101.550003
# 2 1970-01-01 00:00:00.965181600  103.379997
# 3 1970-01-01 00:00:00.965354400  105.199997
# 4 1970-01-01 00:00:00.965613600  106.919998

# %%
print("Min. History:",vnindex_data["time"].min())
print("Max. History:",vnindex_data["time"].max())
# Out:
# Min. History: 1970-01-01 00:00:00.964749600
# Max. History: 1970-01-01 00:00:01.733709600

# %%
vnindex_data.index=vnindex_data["time"]
vnindex_data
# Out:
#                                                        time        close
# time
# 1970-01-01 00:00:00.964749600 1970-01-01 00:00:00.964749600   100.000000
# 1970-01-01 00:00:00.965008800 1970-01-01 00:00:00.965008800   101.550003
# 1970-01-01 00:00:00.965181600 1970-01-01 00:00:00.965181600   103.379997
# 1970-01-01 00:00:00.965354400 1970-01-01 00:00:00.965354400   105.199997
# 1970-01-01 00:00:00.965613600 1970-01-01 00:00:00.965613600   106.919998
# ...                                                     ...          ...
# 1970-01-01 00:00:01.733191200 1970-01-01 00:00:01.733191200  1249.830000
# 1970-01-01 00:00:01.733277600 1970-01-01 00:00:01.733277600  1240.410000
# 1970-01-01 00:00:01.733364000 1970-01-01 00:00:01.733364000  1267.530000
# 1970-01-01 00:00:01.733450400 1970-01-01 00:00:01.733450400  1270.140000
# 1970-01-01 00:00:01.733709600 1970-01-01 00:00:01.733709600  1273.840000
#
# [5894 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# vnindex_data['close'].plot(kind='hist', bins=20, title='close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# vnindex_data['close'].plot(kind='line', figsize=(8, 4), title='close')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
vnindex_data['close'].plot(kind='line', figsize=(8, 4), title='close')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
vnindex_data.drop("time",axis=1,inplace=True)
vnindex_data
# Out:
#                                      close
# time
# 1970-01-01 00:00:00.964749600   100.000000
# 1970-01-01 00:00:00.965008800   101.550003
# 1970-01-01 00:00:00.965181600   103.379997
# 1970-01-01 00:00:00.965354400   105.199997
# 1970-01-01 00:00:00.965613600   106.919998
# ...                                    ...
# 1970-01-01 00:00:01.733191200  1249.830000
# 1970-01-01 00:00:01.733277600  1240.410000
# 1970-01-01 00:00:01.733364000  1267.530000
# 1970-01-01 00:00:01.733450400  1270.140000
# 1970-01-01 00:00:01.733709600  1273.840000
#
# [5894 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# vnindex_data['close'].plot(kind='hist', bins=20, title='close')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# vnindex_data['close'].plot(kind='line', figsize=(8, 4), title='close')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
vnindex_data['close'].plot(kind='line', figsize=(8, 4), title='close')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
result_data=vnindex_data.copy()
plt.figure(figsize=(12,6))
plt.plot(vnindex_data["close"],color="blue");
plt.ylabel("Stock Price")
plt.title("VnIndex Price")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# #### convert to numpy array

# %%
vnindex_data=vnindex_data.values
vnindex_data[0:5]
# Out:
# array([[100.        ],
#        [101.55000305],
#        [103.37999725],
#        [105.19999695],
#        [106.91999817]])

# %% [markdown]
# #### It is necessary to define float 32 for neural network

# %%
vnindex_data=vnindex_data.astype("float32")

# %% [markdown]
# #### Let's make the Train-Test distinction as a function

# %%
def split_data(dataframe,test_size):
    pos=int(round(len(dataframe)*(1-test_size)))
    train=dataframe[:pos]
    test=dataframe[pos:]
    return train,test,pos

train,test,pos=split_data(vnindex_data,0.20)
print(train.shape,test.shape)
# Out:
# (4715, 1) (1179, 1)

# %%
scaler_train=MinMaxScaler(feature_range=(0,1))
train=scaler_train.fit_transform(train)
scaler_test=MinMaxScaler(feature_range=(0,1))
test=scaler_test.fit_transform(test)
train[0:5]
# Out:
# array([[0.        ],
#        [0.00140357],
#        [0.00306068],
#        [0.00470874],
#        [0.00626624]], dtype=float32)

# %%
test[0:5]
# Out:
# array([[0.03688055],
#        [0.03901607],
#        [0.        ],
#        [0.00031167],
#        [0.02074313]], dtype=float32)

# %%
def create_features(data,lookback):
    X,Y=[],[]
    for i in range(lookback,len(data)):
        X.append(data[i-lookback:i,0])
        Y.append(data[i,0])
    return np.array(X),np.array(Y)
lookback=32

# %% [markdown]
# #### Training Dataset

# %%
X_train,y_train=create_features(train,lookback)

# %% [markdown]
# #### Testing Dataset

# %%
X_test,y_test=create_features(test,lookback)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (4683, 32) (4683,) (1147, 32) (1147,)

# %%
X_train[0:5]
# Out:
# array([[0.        , 0.00140357, 0.00306068, 0.00470874, 0.00626624,
#         0.00782375, 0.00938126, 0.01093876, 0.01249627, 0.01405377,
#         0.01561128, 0.01716878, 0.01706012, 0.01539395, 0.01371873,
#         0.0121069 , 0.01132814, 0.01121947, 0.01277698, 0.01456087,
#         0.0163357 , 0.01647153, 0.01648964, 0.01698768, 0.0171869 ,
#         0.01782982, 0.01875345, 0.01894362, 0.01914283, 0.02011175,
#         0.02203146, 0.02395117],
#        [0.00140357, 0.00306068, 0.00470874, 0.00626624, 0.00782375,
#         0.00938126, 0.01093876, 0.01249627, 0.01405377, 0.01561128,
#         0.01716878, 0.01706012, 0.01539395, 0.01371873, 0.0121069 ,
#         0.01132814, 0.01121947, 0.01277698, 0.01456087, 0.0163357 ,
#         0.01647153, 0.01648964, 0.01698768, 0.0171869 , 0.01782982,
#         0.01875345, 0.01894362, 0.01914283, 0.02011175, 0.02203146,
#         0.02395117, 0.0258709 ],
#        [0.00306068, 0.00470874, 0.00626624, 0.00782375, 0.00938126,
#         0.01093876, 0.01249627, 0.01405377, 0.01561128, 0.01716878,
#         0.01706012, 0.01539395, 0.01371873, 0.0121069 , 0.01132814,
#         0.01121947, 0.01277698, 0.01456087, 0.0163357 , 0.01647153,
#         0.01648964, 0.01698768, 0.0171869 , 0.01782982, 0.01875345,
#         0.01894362, 0.01914283, 0.02011175, 0.02203146, 0.02395117,
#         0.0258709 , 0.02780873],
#        [0.00470874, 0.00626624, 0.00782375, 0.00938126, 0.01093876,
#         0.01249627, 0.01405377, 0.01561128, 0.01716878, 0.01706012,
#         0.01539395, 0.01371873, 0.0121069 , 0.01132814, 0.01121947,
#         0.01277698, 0.01456087, 0.0163357 , 0.01647153, 0.01648964,
#         0.01698768, 0.0171869 , 0.01782982, 0.01875345, 0.01894362,
#         0.01914283, 0.02011175, 0.02203146, 0.02395117, 0.0258709 ,
#         0.02780873, 0.02974655],
#        [0.00626624, 0.00782375, 0.00938126, 0.01093876, 0.01249627,
#         0.01405377, 0.01561128, 0.01716878, 0.01706012, 0.01539395,
#         0.01371873, 0.0121069 , 0.01132814, 0.01121947, 0.01277698,
#         0.01456087, 0.0163357 , 0.01647153, 0.01648964, 0.01698768,
#         0.0171869 , 0.01782982, 0.01875345, 0.01894362, 0.01914283,
#         0.02011175, 0.02203146, 0.02395117, 0.0258709 , 0.02780873,
#         0.02974655, 0.03172965]], dtype=float32)

# %% [markdown]
# #### There are 20 features in total here, so we added the day 20 days before the relevant date to the data set.

# %%
y_test[0:5]
# Out:
# array([0.19639623, 0.19019753, 0.20171762, 0.21200264, 0.22007132],
#       dtype=float32)

# %% [markdown]
# #### stock closing prices

# %%
X_train=np.reshape(X_train,(X_train.shape[0],1,X_train.shape[1]))
X_test=np.reshape(X_test,(X_test.shape[0],1,X_test.shape[1]))
y_train=y_train.reshape(-1,1)
y_test=y_test.reshape(-1,1)
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (4683, 1, 32) (4683, 1) (1147, 1, 32) (1147, 1)

# %% [markdown]
# # 4- Modeling

# %% [markdown]
# Dựa trên kết quả huấn luyện, bạn đã gặp vấn đề với **early stopping** do `val_loss` không cải thiện sau 3 epoch liên tiếp. Điều này có thể xảy ra khi mô hình của bạn bị **overfitting**, **underfitting**, hoặc cấu trúc mô hình và tham số tối ưu chưa phù hợp. Để cải thiện, bạn có thể thực hiện các điều chỉnh sau:
#
# ---
#
# ### 1. **Điều chỉnh cấu trúc mô hình**:
# - **Tăng số lượng đơn vị LSTM**:
#   ```python
#   model.add(LSTM(units=100, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], lookback)))
#   model.add(LSTM(units=50, activation="relu"))
#   ```
#   Thêm một lớp LSTM với `return_sequences=True` để giữ thông tin qua các bước thời gian.
#
# - **Tăng số tầng Dense**:
#   ```python
#   model.add(Dense(units=10, activation="relu"))
#   model.add(Dense(units=1))
#   ```
#
# - **Thử các hàm kích hoạt khác**:
#   - `tanh` hoặc `sigmoid` có thể hoạt động tốt với dữ liệu chuỗi thời gian.
#
# ---
#
# ### 2. **Điều chỉnh tham số tối ưu hóa**:
# - **Học suất (learning rate)**:
#   Sử dụng `Adam` với learning rate thấp hơn:
#   ```python
#   from tensorflow.keras.optimizers import Adam
#   model.compile(loss="mean_squared_error", optimizer=Adam(learning_rate=0.001))
#   ```
#
# - **Thay đổi hàm mất mát**:
#   Nếu dữ liệu có outliers, sử dụng hàm `Huber`:
#   ```python
#   model.compile(loss="huber", optimizer="adam")
#   ```
#
# ---
#
# ### 3. **Cải thiện kỹ thuật huấn luyện**:
# - **Tăng patience cho EarlyStopping**:
#   ```python
#   callbacks = [EarlyStopping(monitor="val_loss", patience=10, verbose=1, mode="min")]
#   ```
#
# - **Thay đổi batch_size**:
#   Thử nghiệm với các giá trị khác (16, 32, hoặc 64).
#
# - **Shuffling dữ liệu**:
#   Nếu dữ liệu không phụ thuộc hoàn toàn vào thứ tự thời gian:
#   ```python
#   history = model.fit(x=X_train, y=y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), callbacks=callbacks, shuffle=True)
#   ```
#
# ---
#
# ### 4. **Tiền xử lý dữ liệu tốt hơn**:
# - **Chuẩn hóa (Normalization)**:
#   Chuẩn hóa tất cả các đặc trưng (features) về cùng khoảng giá trị:
#   ```python
#   from sklearn.preprocessing import MinMaxScaler
#   scaler = MinMaxScaler()
#   X_train = scaler.fit_transform(X_train)
#   X_test = scaler.transform(X_test)
#   ```
#
# - **Thử nghiệm các giá trị `lookback` khác**:
#   Xem xét tăng/giảm số bước thời gian trong quá khứ:
#   ```python
#   lookback = 30  # Số ngày quá khứ
#   ```
#
# ---
#
# ### 5. **Thử nghiệm các kiến trúc nâng cao**:
# - **GRU (Gated Recurrent Units)**:
#   GRU thường ít phức tạp hơn LSTM nhưng hiệu quả tương tự:
#   ```python
#   from tensorflow.keras.layers import GRU
#   model.add(GRU(units=50, activation="relu", input_shape=(X_train.shape[1], lookback)))
#   ```
#
# - **Attention Mechanism**:
#   Thêm cơ chế Attention để cải thiện khả năng học các mẫu phức tạp.
#
# ---
#
# ### 6. **Theo dõi hiệu suất**:
# - Vẽ đồ thị loss và val_loss:
#   ```python
#   import matplotlib.pyplot as plt
#   plt.plot(history.history['loss'], label='Training Loss')
#   plt.plot(history.history['val_loss'], lƯabel='Validation Loss')
#   plt.legend()
#   plt.show()
#   ```
#
# Hãy thử từng bước cải thiện trên và quan sát sự thay đổi. Nếu cần thêm hỗ trợ, hãy chia sẻ thông tin về cấu trúc dữ liệu và hiệu suất mô hình hiện tại!

# %%
model=Sequential()
#model.add(LSTM(units=50,
#              activation="relu",
#              input_shape=(X_train.shape[1],lookback)))
model.add(LSTM(units=100, activation="relu", return_sequences=True, input_shape=(X_train.shape[1], lookback)))
model.add(LSTM(units=50, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(1))
#model.add(Dense(units=10, activation="relu"))
#model.add(Dense(units=1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 1, 100)              │          53,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          30,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 83,451 (325.98 KB)
#  Trainable params: 83,451 (325.98 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Setting optimization and evaluation metrics

# %%
from tensorflow.keras.optimizers import Adam
#model.compile(loss="mean_squared_error",optimizer="adam")
#model.compile(loss="mean_squared_error", optimizer=Adam(learning_rate=0.001))
model.compile(loss="huber", optimizer="adam")
callbacks=[EarlyStopping(monitor="val_loss",patience=10,verbose=1,mode="min"),
          ModelCheckpoint(filepath="mymodel.keras",monitor="val_loss",mode="min",
                         save_best_only=True,save_weights_only=False,verbose=1)]

history = model.fit(x=X_train,
                    y=y_train,
                    epochs=100,
                    batch_size=64,
                    validation_data=(X_test,y_test),
                    callbacks=callbacks,
                    shuffle=False)
# Out:
# Epoch 1/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0149
# Epoch 1: val_loss improved from inf to 0.00770, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0149 - val_loss: 0.0077
# Epoch 2/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023
# Epoch 2: val_loss did not improve from 0.00770
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0024 - val_loss: 0.0083
# Epoch 3/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022
# Epoch 3: val_loss improved from 0.00770 to 0.00591, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023 - val_loss: 0.0059
# Epoch 4/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023
# Epoch 4: val_loss improved from 0.00591 to 0.00550, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0024 - val_loss: 0.0055
# Epoch 5/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0022
# Epoch 5: val_loss improved from 0.00550 to 0.00428, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 6/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021
# Epoch 6: val_loss improved from 0.00428 to 0.00376, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 7/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022
# Epoch 7: val_loss did not improve from 0.00376
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 8/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022
# Epoch 8: val_loss did not improve from 0.00376
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023 - val_loss: 0.0039
# Epoch 9/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017
# Epoch 9: val_loss improved from 0.00376 to 0.00296, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 10/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020
# Epoch 10: val_loss improved from 0.00296 to 0.00284, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 11/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 11: val_loss improved from 0.00284 to 0.00201, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 12/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017
# Epoch 12: val_loss did not improve from 0.00201
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 13/100
# 69/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018
# Epoch 13: val_loss did not improve from 0.00201
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018 - val_loss: 0.0026
# Epoch 14/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0014
# Epoch 14: val_loss improved from 0.00201 to 0.00179, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 15/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013
# Epoch 15: val_loss did not improve from 0.00179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 16/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 16: val_loss did not improve from 0.00179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 17/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 17: val_loss did not improve from 0.00179
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 18/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 18: val_loss improved from 0.00179 to 0.00122, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 19/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016
# Epoch 19: val_loss did not improve from 0.00122
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 20/100
# 65/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 20: val_loss did not improve from 0.00122
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 21/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 21: val_loss improved from 0.00122 to 0.00119, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 22/100
# 65/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013
# Epoch 22: val_loss did not improve from 0.00119
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 23/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2690e-04
# Epoch 23: val_loss improved from 0.00119 to 0.00115, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.5189e-04 - val_loss: 0.0012
# Epoch 24/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 24: val_loss improved from 0.00115 to 0.00113, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 25/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 25: val_loss improved from 0.00113 to 0.00093, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 9.3367e-04
# Epoch 26/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6071e-04
# Epoch 26: val_loss did not improve from 0.00093
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7210e-04 - val_loss: 0.0011
# Epoch 27/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7176e-04
# Epoch 27: val_loss improved from 0.00093 to 0.00083, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9948e-04 - val_loss: 8.3456e-04
# Epoch 28/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.3117e-04
# Epoch 28: val_loss did not improve from 0.00083
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.4260e-04 - val_loss: 8.7309e-04
# Epoch 29/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8998e-04
# Epoch 29: val_loss improved from 0.00083 to 0.00068, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.0685e-04 - val_loss: 6.8155e-04
# Epoch 30/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.5255e-04
# Epoch 30: val_loss did not improve from 0.00068
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.5818e-04 - val_loss: 8.4604e-04
# Epoch 31/100
# 65/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6869e-04
# Epoch 31: val_loss did not improve from 0.00068
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.2848e-04 - val_loss: 7.7410e-04
# Epoch 32/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9539e-04
# Epoch 32: val_loss improved from 0.00068 to 0.00059, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1390e-04 - val_loss: 5.9086e-04
# Epoch 33/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1825e-04
# Epoch 33: val_loss did not improve from 0.00059
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6182e-04 - val_loss: 5.9569e-04
# Epoch 34/100
# 69/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1029e-04
# Epoch 34: val_loss improved from 0.00059 to 0.00056, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.4339e-04 - val_loss: 5.6441e-04
# Epoch 35/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8081e-04
# Epoch 35: val_loss did not improve from 0.00056
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.0760e-04 - val_loss: 5.8283e-04
# Epoch 36/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5281e-04
# Epoch 36: val_loss improved from 0.00056 to 0.00054, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.5803e-04 - val_loss: 5.4318e-04
# Epoch 37/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5268e-04
# Epoch 37: val_loss did not improve from 0.00054
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.7728e-04 - val_loss: 5.8979e-04
# Epoch 38/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8706e-04
# Epoch 38: val_loss improved from 0.00054 to 0.00054, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.9206e-04 - val_loss: 5.3836e-04
# Epoch 39/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5227e-04
# Epoch 39: val_loss did not improve from 0.00054
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.7378e-04 - val_loss: 5.4258e-04
# Epoch 40/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9142e-04
# Epoch 40: val_loss improved from 0.00054 to 0.00054, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1260e-04 - val_loss: 5.3519e-04
# Epoch 41/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7022e-04
# Epoch 41: val_loss did not improve from 0.00054
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.9375e-04 - val_loss: 8.6261e-04
# Epoch 42/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5808e-04
# Epoch 42: val_loss improved from 0.00054 to 0.00052, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8062e-04 - val_loss: 5.2376e-04
# Epoch 43/100
# 65/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7521e-04
# Epoch 43: val_loss did not improve from 0.00052
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.1133e-04 - val_loss: 5.4510e-04
# Epoch 44/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 44: val_loss did not improve from 0.00052
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - val_loss: 5.6519e-04
# Epoch 45/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2007e-04
# Epoch 45: val_loss did not improve from 0.00052
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.5893e-04 - val_loss: 8.3467e-04
# Epoch 46/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8756e-04
# Epoch 46: val_loss did not improve from 0.00052
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9771e-04 - val_loss: 5.2466e-04
# Epoch 47/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5788e-04
# Epoch 47: val_loss did not improve from 0.00052
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8071e-04 - val_loss: 5.9933e-04
# Epoch 48/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3463e-04
# Epoch 48: val_loss improved from 0.00052 to 0.00051, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.4446e-04 - val_loss: 5.0757e-04
# Epoch 49/100
# 69/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8379e-04
# Epoch 49: val_loss did not improve from 0.00051
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.0387e-04 - val_loss: 5.1233e-04
# Epoch 50/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4539e-04
# Epoch 50: val_loss improved from 0.00051 to 0.00050, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6145e-04 - val_loss: 4.9612e-04
# Epoch 51/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7648e-04
# Epoch 51: val_loss did not improve from 0.00050
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.0021e-04 - val_loss: 6.1180e-04
# Epoch 52/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9066e-04
# Epoch 52: val_loss did not improve from 0.00050
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.1536e-04 - val_loss: 5.9802e-04
# Epoch 53/100
# 65/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9442e-04
# Epoch 53: val_loss did not improve from 0.00050
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.1130e-04 - val_loss: 5.0411e-04
# Epoch 54/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4358e-04
# Epoch 54: val_loss improved from 0.00050 to 0.00049, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.5167e-04 - val_loss: 4.9170e-04
# Epoch 55/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8950e-04
# Epoch 55: val_loss did not improve from 0.00049
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.9521e-04 - val_loss: 6.0944e-04
# Epoch 56/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7209e-04
# Epoch 56: val_loss improved from 0.00049 to 0.00049, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7817e-04 - val_loss: 4.8806e-04
# Epoch 57/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1561e-04
# Epoch 57: val_loss improved from 0.00049 to 0.00047, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.2540e-04 - val_loss: 4.6682e-04
# Epoch 58/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7497e-04
# Epoch 58: val_loss did not improve from 0.00047
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8626e-04 - val_loss: 4.7102e-04
# Epoch 59/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9701e-04
# Epoch 59: val_loss did not improve from 0.00047
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.1615e-04 - val_loss: 6.6876e-04
# Epoch 60/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9749e-04
# Epoch 60: val_loss did not improve from 0.00047
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0672e-04 - val_loss: 5.4524e-04
# Epoch 61/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5667e-04
# Epoch 61: val_loss improved from 0.00047 to 0.00045, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7072e-04 - val_loss: 4.5444e-04
# Epoch 62/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9219e-04
# Epoch 62: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9675e-04 - val_loss: 5.1724e-04
# Epoch 63/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6426e-04
# Epoch 63: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6615e-04 - val_loss: 4.5735e-04
# Epoch 64/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4489e-04
# Epoch 64: val_loss improved from 0.00045 to 0.00045, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.4692e-04 - val_loss: 4.5027e-04
# Epoch 65/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2992e-04
# Epoch 65: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3403e-04 - val_loss: 4.8155e-04
# Epoch 66/100
# 69/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6779e-04
# Epoch 66: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.7532e-04 - val_loss: 4.9172e-04
# Epoch 67/100
# 69/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2498e-04
# Epoch 67: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.3491e-04 - val_loss: 4.6295e-04
# Epoch 68/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8411e-04
# Epoch 68: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.8914e-04 - val_loss: 5.1046e-04
# Epoch 69/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8932e-04
# Epoch 69: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.9140e-04 - val_loss: 7.2206e-04
# Epoch 70/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6276e-04
# Epoch 70: val_loss did not improve from 0.00045
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7446e-04 - val_loss: 4.7892e-04
# Epoch 71/100
# 65/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5311e-04
# Epoch 71: val_loss improved from 0.00045 to 0.00042, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.5740e-04 - val_loss: 4.2283e-04
# Epoch 72/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8027e-04
# Epoch 72: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.8333e-04 - val_loss: 4.6973e-04
# Epoch 73/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7872e-04
# Epoch 73: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.9260e-04 - val_loss: 5.3285e-04
# Epoch 74/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9235e-04
# Epoch 74: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.9706e-04 - val_loss: 6.9780e-04
# Epoch 75/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0524e-04
# Epoch 75: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.1343e-04 - val_loss: 4.5500e-04
# Epoch 76/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5534e-04
# Epoch 76: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.5957e-04 - val_loss: 4.4566e-04
# Epoch 77/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7094e-04
# Epoch 77: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.7349e-04 - val_loss: 4.4469e-04
# Epoch 78/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0656e-04
# Epoch 78: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.1179e-04 - val_loss: 4.8087e-04
# Epoch 79/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 79: val_loss did not improve from 0.00042
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 5.3386e-04
# Epoch 80/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7679e-04
# Epoch 80: val_loss improved from 0.00042 to 0.00040, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.8087e-04 - val_loss: 4.0230e-04
# Epoch 81/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5076e-04
# Epoch 81: val_loss did not improve from 0.00040
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.5718e-04 - val_loss: 4.3715e-04
# Epoch 82/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8529e-04
# Epoch 82: val_loss did not improve from 0.00040
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.8640e-04 - val_loss: 4.1539e-04
# Epoch 83/100
# 65/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6723e-04
# Epoch 83: val_loss did not improve from 0.00040
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.7252e-04 - val_loss: 4.2564e-04
# Epoch 84/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9702e-04
# Epoch 84: val_loss did not improve from 0.00040
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 8.0334e-04 - val_loss: 5.2871e-04
# Epoch 85/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8867e-04
# Epoch 85: val_loss did not improve from 0.00040
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9103e-04 - val_loss: 5.7317e-04
# Epoch 86/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011
# Epoch 86: val_loss did not improve from 0.00040
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 5.3841e-04
# Epoch 87/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5692e-04
# Epoch 87: val_loss improved from 0.00040 to 0.00039, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.5227e-04 - val_loss: 3.9096e-04
# Epoch 88/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3105e-04
# Epoch 88: val_loss improved from 0.00039 to 0.00039, saving model to mymodel.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.3250e-04 - val_loss: 3.8784e-04
# Epoch 89/100
# 68/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6067e-04
# Epoch 89: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5914e-04 - val_loss: 4.0684e-04
# Epoch 90/100
# 66/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1473e-04
# Epoch 90: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.2130e-04 - val_loss: 6.9009e-04
# Epoch 91/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7524e-04
# Epoch 91: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.7276e-04 - val_loss: 6.4556e-04
# Epoch 92/100
# 70/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012
# Epoch 92: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - val_loss: 7.4475e-04
# Epoch 93/100
# 67/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010
# Epoch 93: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - val_loss: 7.1565e-04
# Epoch 94/100
# 72/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019
# Epoch 94: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0019 - val_loss: 4.5039e-04
# Epoch 95/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6361e-04
# Epoch 95: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.6391e-04 - val_loss: 9.0213e-04
# Epoch 96/100
# 73/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 96: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0017 - val_loss: 7.0930e-04
# Epoch 97/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5626e-04
# Epoch 97: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5692e-04 - val_loss: 6.8737e-04
# Epoch 98/100
# 71/74 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017
# Epoch 98: val_loss did not improve from 0.00039
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - val_loss: 7.4316e-04
# Epoch 98: early stopping

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,2)
plt.plot(history.history["loss"],label="Training Loss")
plt.plot(history.history["val_loss"],label="Validation Loss")
plt.legend(loc="upper right")
plt.xlabel("Epoch",fontsize=16)
plt.ylabel("Loss",fontsize=16)
plt.ylim([0,max(plt.ylim())])
plt.title("Training and Validation Loss",fontsize=16)
plt.show()

# %% [markdown]
# #### (The expression loss is the mean squared error value, that is, the mean squared expression of the actual values and the estimated values.)

# %% [markdown]
# # 5-Evaluation

# %%
loss=model.evaluate(X_test,y_test,batch_size=20)
# Out:
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8727e-04

# %%
print("\nTest loss:%.1f%%"%(100.0*loss))
# Out:
# Test loss:0.1%

# %%
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
train_predict=scaler_train.inverse_transform(train_predict)
test_predict=scaler_test.inverse_transform(test_predict)
y_train=scaler_train.inverse_transform(y_train)
y_test=scaler_test.inverse_transform(y_test)
# Out:
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# #### RMSE value to train dataset

# %%
train_rmse=np.sqrt(mean_squared_error(y_train,train_predict))
test_rmse=np.sqrt(mean_squared_error(y_test,test_predict,))
print(f"Train RMSE:{train_rmse}")
print(f"Test RMSE:{test_rmse}")
# Out:
# Train RMSE:26.24827003228022
# Test RMSE:33.39861019692193

# %% [markdown]
# #### The mistake that vninedex will be made in the next period is??

# %%
train_prediction_data=result_data[lookback:pos]
train_prediction_data["Predicted"]=train_predict
train_prediction_data.tail()
# Out:
#                                    close   Predicted
# time
# 1970-01-01 00:00:01.584583200  725.94000  739.772766
# 1970-01-01 00:00:01.584669600  709.72998  725.980164
# 1970-01-01 00:00:01.584928800  666.59003  712.134644
# 1970-01-01 00:00:01.585015200  659.21002  693.010254
# 1970-01-01 00:00:01.585101600  690.25000  676.477905

# %%
test_prediction_data=result_data[pos+lookback:]
test_prediction_data["Predicted"]=test_predict
test_prediction_data.tail()
# Out:
#                                  close    Predicted
# time
# 1970-01-01 00:00:01.733191200  1249.83  1212.438354
# 1970-01-01 00:00:01.733277600  1240.41  1214.750366
# 1970-01-01 00:00:01.733364000  1267.53  1214.274292
# 1970-01-01 00:00:01.733450400  1270.14  1219.206909
# 1970-01-01 00:00:01.733709600  1273.84  1224.869751

# %%
plt.figure(figsize=(14,5))
plt.plot(result_data,label="Real Values")
plt.plot(train_prediction_data["Predicted"],color="blue",label="Train Predicted")
plt.plot(test_prediction_data["Predicted"],color="red",label="Test Predicted")
plt.xlabel("Time")
plt.ylabel("Stock Values")
plt.legend()
plt.show()

# %% [markdown]
# ### (If we forecast in a certain period, we will conclude that we forecast 32 below or 32 above.)
